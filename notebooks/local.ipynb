# %% [markdown]
# # Local files
#
# NiiVue can either download files from a URL or load local images. This demo displays an image in the local images folder.

# %%
from ipyniivue import NiiVue

nv = NiiVue()
nv.load_volumes([{"path": "../images/mni152.nii.gz"}])
nv
