# %% [markdown]
# # ipyniivue — Minimal demo
#
# This notebook demonstrates the minimal usage of `NiiVue` loading a single local NIfTI image.

# %%
from ipyniivue import NiiVue

nv = NiiVue()
nv.load_volumes([{'path': '../images/mni152.nii.gz'}])
nv
