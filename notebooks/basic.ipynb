# %% [markdown]
# # Minimal NiiVue instance
#
# This notebook downloads and displays a T1-weighted MRI scan.

# %%
from pathlib import Path

import ipyniivue
from ipyniivue import NiiVue, SliceType, download_dataset

BASE_API_URL = "https://niivue.com/demos/images/"
DATA_FOLDER = Path(ipyniivue.__file__).parent / "images"
# Download data for example
download_dataset(
    BASE_API_URL,
    DATA_FOLDER,
    files=[
        "mni152.nii.gz",
    ],
)
# based on https://niivue.github.io/niivue/features/basic.multiplanar.html

volumes = [
    {
        "path": DATA_FOLDER / "mni152.nii.gz",
    },
]
nv = NiiVue(slice_type=SliceType.RENDER)
nv.load_volumes(volumes)
nv
